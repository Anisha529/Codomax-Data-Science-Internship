# %%
import pandas as pd
dict1={
    "Name":["Rahul","Priya","Rohan","Anushka","Pritam"],
    "Department":["CSE","ECE","ECE","CSE","CSE"],
    "Marks":[85,96,74,87,92],
    "City":["Delhi","Mumbai","Kolkata","Lucknow","Chennai"]
}
df=pd.DataFrame(dict1)
df.to_csv('student_record.csv',index=False)
print(df)
# Out:
#       Name Department  Marks     City
# 0    Rahul        CSE     85    Delhi
# 1    Priya        ECE     96   Mumbai
# 2    Rohan        ECE     74  Kolkata
# 3  Anushka        CSE     87  Lucknow
# 4   Pritam        CSE     92  Chennai

# %%
import pandas as pd
df=pd.read_csv('student_record.csv')
print(df.shape)
# Out:
# (5, 4)

# %%
import pandas as pd
df=pd.read_csv('student_record.csv')
print(df.head())
# Out:
#       Name Department  Marks     City
# 0    Rahul        CSE     85    Delhi
# 1    Priya        ECE     96   Mumbai
# 2    Rohan        ECE     74  Kolkata
# 3  Anushka        CSE     87  Lucknow
# 4   Pritam        CSE     92  Chennai

# %%
import pandas as pd
df=pd.read_csv('student_record.csv')
print(df.columns)
# Out:
# Index(['Name', 'Department', 'Marks', 'City'], dtype='str')

# %%
import pandas as pd
df=pd.read_csv('student_record.csv')
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        5 non-null      str
#  1   Department  5 non-null      str
#  2   Marks       5 non-null      int64
#  3   City        5 non-null      str
# dtypes: int64(1), str(3)
# memory usage: 292.0 bytes
# None
